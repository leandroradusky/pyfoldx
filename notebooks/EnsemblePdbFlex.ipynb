# %% [markdown]
# # Working with pdbFlex trajectories ensembles

# %%
# This simulates the installation the user will just import pyFoldx.Ensemble
import sys
sys.path.append("/home/lradusky/Dropbox/workspacesbg/pyFoldX")

# %%
from src.structure.Ensemble import Ensemble, pdbFlexEnsemble

# %%
pdbFlexCode = "4ht3A"
pdbFlexPath = "/home/lradusky/Downloads/%s/" % pdbFlexCode 
outPath = "/home/lradusky/Downloads/outputTraj/"

t = pdbFlexEnsemble(pdbFlexCode, outPath, pdbFlexPath)
t.saveToPDB(outPath+"%s_traj.pdb" % pdbFlexCode)
# Out:
# Processing configurations (total: 69)
# 100%|██████████| 69/69 [02:30<00:00,  2.18s/it]
# Configurations processed
# MasterStructure is 4ht3A:
# Aligning to master (total: 69)
# 69it [00:16,  4.18it/s]
# Ensemble built
# ...

# %%
t.getTotalEnergy()
# Out:
# Computing total energy for ensemble...
#   0%|          | 0/69 [00:00<?, ?it/s]
# /home/lradusky/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 100%|██████████| 69/69 [04:10<00:00,  3.63s/it]
# Energy computed.
#               total   backHbond  sideHbond  energy_VdW    electro  \
# 4ht3A_A   28.448794 -197.403193 -36.744797 -319.012517 -12.801824
# 2cloA_A   58.725809 -180.403280 -31.504933 -304.517073 -14.219133
# 4xugA_A   14.825549 -193.010987 -37.611280 -315.901225 -14.202568
# 5cgqA_A   19.203492 -195.247552 -38.510029 -317.898285 -12.676080
# 4y6gA_A   11.333436 -188.962874 -35.112172 -303.150725 -13.742131
# ...             ...         ...        ...         ...        ...
# ...
